# %% [markdown]
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# DATA READING AND CLEANING

# %%
df=pd.read_csv('Raw_Data_Singapore credit Dataset.csv')
df
# Out:
#     checking_balance  months_loan_duration credit_history  \
# 0            < 0 SGD                     6       critical
# 1        1 - 200 SGD                    48           good
# 2            unknown                    12       critical
# 3            < 0 SGD                    42           good
# 4            < 0 SGD                    24           poor
# ..               ...                   ...            ...
# 995          unknown                    12           good
# 996          < 0 SGD                    30           good
# 997          unknown                    12           good
# 998          < 0 SGD                    45           good
# 999      1 - 200 SGD                    45       critical
#
#                   purpose  amount savings_balance employment_duration  \
# 0    furniture/appliances    1169         unknown           > 7 years
# 1    furniture/appliances    5951       < 100 SGD         1 - 4 years
# ...

# %%
df.head()
# Out:
#   checking_balance  months_loan_duration credit_history               purpose  \
# 0          < 0 SGD                     6       critical  furniture/appliances
# 1      1 - 200 SGD                    48           good  furniture/appliances
# 2          unknown                    12       critical             education
# 3          < 0 SGD                    42           good  furniture/appliances
# 4          < 0 SGD                    24           poor                   car
#
#    amount savings_balance employment_duration  percent_of_income  \
# 0    1169         unknown           > 7 years                  4
# 1    5951       < 100 SGD         1 - 4 years                  2
# 2    2096       < 100 SGD         4 - 7 years                  2
# 3    7882       < 100 SGD         4 - 7 years                  2
# 4    4870       < 100 SGD         1 - 4 years                  3
#
#    years_at_residence  age other_credit housing  existing_loans_count  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   checking_balance      1000 non-null   object
#  1   months_loan_duration  1000 non-null   int64
#  2   credit_history        1000 non-null   object
#  3   purpose               1000 non-null   object
#  4   amount                1000 non-null   int64
#  5   savings_balance       1000 non-null   object
#  6   employment_duration   1000 non-null   object
#  7   percent_of_income     1000 non-null   int64
#  8   years_at_residence    1000 non-null   int64
#  9   age                   1000 non-null   int64
#  10  other_credit          1000 non-null   object
#  11  housing               1000 non-null   object
#  12  existing_loans_count  1000 non-null   int64
#  13  job                   1000 non-null   object
#  14  dependents            1000 non-null   int64
# ...

# %%
df.describe()
# Out:
#        months_loan_duration        amount  percent_of_income  \
# count           1000.000000   1000.000000        1000.000000
# mean              20.903000   3271.258000           2.973000
# std               12.058814   2822.736876           1.118715
# min                4.000000    250.000000           1.000000
# 25%               12.000000   1365.500000           2.000000
# 50%               18.000000   2319.500000           3.000000
# 75%               24.000000   3972.250000           4.000000
# max               72.000000  18424.000000           4.000000
#
#        years_at_residence          age  existing_loans_count   dependents
# count         1000.000000  1000.000000           1000.000000  1000.000000
# mean             2.845000    35.546000              1.407000     1.155000
# std              1.103718    11.375469              0.577654     0.362086
# min              1.000000    19.000000              1.000000     1.000000
# ...

# %%
df.columns
# Out:
# Index(['checking_balance', 'months_loan_duration', 'credit_history', 'purpose',
#        'amount', 'savings_balance', 'employment_duration', 'percent_of_income',
#        'years_at_residence', 'age', 'other_credit', 'housing',
#        'existing_loans_count', 'job', 'dependents', 'phone', 'default'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.iloc[0:5]
# Out:
#   checking_balance  months_loan_duration credit_history               purpose  \
# 0          < 0 SGD                     6       critical  furniture/appliances
# 1      1 - 200 SGD                    48           good  furniture/appliances
# 2          unknown                    12       critical             education
# 3          < 0 SGD                    42           good  furniture/appliances
# 4          < 0 SGD                    24           poor                   car
#
#    amount savings_balance employment_duration  percent_of_income  \
# 0    1169         unknown           > 7 years                  4
# 1    5951       < 100 SGD         1 - 4 years                  2
# 2    2096       < 100 SGD         4 - 7 years                  2
# 3    7882       < 100 SGD         4 - 7 years                  2
# 4    4870       < 100 SGD         1 - 4 years                  3
#
#    years_at_residence  age other_credit housing  existing_loans_count  \
# ...

# %%
df.tail()
# Out:
#     checking_balance  months_loan_duration credit_history  \
# 995          unknown                    12           good
# 996          < 0 SGD                    30           good
# 997          unknown                    12           good
# 998          < 0 SGD                    45           good
# 999      1 - 200 SGD                    45       critical
#
#                   purpose  amount savings_balance employment_duration  \
# 995  furniture/appliances    1736       < 100 SGD         4 - 7 years
# 996                   car    3857       < 100 SGD         1 - 4 years
# 997  furniture/appliances     804       < 100 SGD           > 7 years
# 998  furniture/appliances    1845       < 100 SGD         1 - 4 years
# 999                   car    4576   100 - 500 SGD          unemployed
#
#      percent_of_income  years_at_residence  age other_credit housing  \
# 995                  3                   4   31         none     own
# ...

# %%
df.isnull().sum()
# Out:
# checking_balance        0
# months_loan_duration    0
# credit_history          0
# purpose                 0
# amount                  0
# savings_balance         0
# employment_duration     0
# percent_of_income       0
# years_at_residence      0
# age                     0
# other_credit            0
# housing                 0
# existing_loans_count    0
# job                     0
# dependents              0
# phone                   0
# default                 0
# dtype: int64

# %%
df.dropna()
#removes the row with empty value
# Out:
#     checking_balance  months_loan_duration credit_history  \
# 0            < 0 SGD                     6       critical
# 1        1 - 200 SGD                    48           good
# 2            unknown                    12       critical
# 3            < 0 SGD                    42           good
# 4            < 0 SGD                    24           poor
# ..               ...                   ...            ...
# 995          unknown                    12           good
# 996          < 0 SGD                    30           good
# 997          unknown                    12           good
# 998          < 0 SGD                    45           good
# 999      1 - 200 SGD                    45       critical
#
#                   purpose  amount savings_balance employment_duration  \
# 0    furniture/appliances    1169         unknown           > 7 years
# 1    furniture/appliances    5951       < 100 SGD         1 - 4 years
# ...

# %%
df.drop_duplicates()
#removes the value with duplicates
# Out:
#     checking_balance  months_loan_duration credit_history  \
# 0            < 0 SGD                     6       critical
# 1        1 - 200 SGD                    48           good
# 2            unknown                    12       critical
# 3            < 0 SGD                    42           good
# 4            < 0 SGD                    24           poor
# ..               ...                   ...            ...
# 995          unknown                    12           good
# 996          < 0 SGD                    30           good
# 997          unknown                    12           good
# 998          < 0 SGD                    45           good
# 999      1 - 200 SGD                    45       critical
#
#                   purpose  amount savings_balance employment_duration  \
# 0    furniture/appliances    1169         unknown           > 7 years
# 1    furniture/appliances    5951       < 100 SGD         1 - 4 years
# ...

# %%
df.fillna(0.00)
# Out:
#     checking_balance  months_loan_duration credit_history  \
# 0            < 0 SGD                     6       critical
# 1        1 - 200 SGD                    48           good
# 2            unknown                    12       critical
# 3            < 0 SGD                    42           good
# 4            < 0 SGD                    24           poor
# ..               ...                   ...            ...
# 995          unknown                    12           good
# 996          < 0 SGD                    30           good
# 997          unknown                    12           good
# 998          < 0 SGD                    45           good
# 999      1 - 200 SGD                    45       critical
#
#                   purpose  amount savings_balance employment_duration  \
# 0    furniture/appliances    1169         unknown           > 7 years
# 1    furniture/appliances    5951       < 100 SGD         1 - 4 years
# ...

# %%
df['job'].value_counts()
# Out:
# job
# skilled       630
# unskilled     200
# management    148
# unemployed     22
# Name: count, dtype: int64

# %%
df['credit_history'].value_counts()
# Out:
# credit_history
# good         530
# critical     293
# poor          88
# very good     49
# perfect       40
# Name: count, dtype: int64

# %%
df['purpose'].value_counts()
# Out:
# purpose
# furniture/appliances    473
# car                     337
# business                 97
# education                59
# renovations              22
# car0                     12
# Name: count, dtype: int64

# %%
df['housing'].value_counts()
# Out:
# housing
# own      713
# rent     179
# other    108
# Name: count, dtype: int64

# %% [markdown]
# DATA ANALYSIS AND GRAPHICAL REPRESENTATION

# %%
df.months_loan_duration.plot()
# Out:
# <Axes: >

# %%
df.amount.plot()
# Out:
# <Axes: >

# %%
df.age.plot()
# Out:
# <Axes: >

# %%
df.years_at_residence.plot()
# Out:
# <Axes: >

# %%
df['months_loan_duration'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['age'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.percent_of_income.plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.years_at_residence.plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(x='percent_of_income',y='amount',kind='scatter')
# Out:
# <Axes: xlabel='percent_of_income', ylabel='amount'>

# %%
df.plot(x='years_at_residence',y='age',kind='scatter')
# Out:
# <Axes: xlabel='years_at_residence', ylabel='age'>

# %%
df.plot(x='years_at_residence' , y='percent_of_income',kind='scatter')
# Out:
# <Axes: xlabel='years_at_residence', ylabel='percent_of_income'>

# %%
sns.heatmap(df[['months_loan_duration',  
       'amount','percent_of_income',
       'years_at_residence', 'age', 
       'existing_loans_count']].corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df[['months_loan_duration',  
       'amount','percent_of_income',
       'years_at_residence', 'age', 
       'existing_loans_count']])
# Out:
# N:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
